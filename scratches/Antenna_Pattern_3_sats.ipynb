# %%
import sympy
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from sympy import sin, cos, pi, Function
from sympy import Symbol, symbols, Matrix, Transpose, init_session, Array, tensorproduct
from sympy.physics.vector import ReferenceFrame, outer, dynamicsymbols, Point

# %% [markdown]
# ## Definindo as funções para h e psi

# %%
#Defining h
def h(t, L, w, e_mais, e_cruzado,A):
	h_mais = A*cos(w*t-w*L)
	h_cruzado = A*sin(w*t-w*L)
	return h_mais*e_mais + h_cruzado*e_cruzado

# %% [markdown]
# \begin{equation}
#  h = h_+ + h_\times
# \end{equation}

# %%
#função PSI(t)
def PSIj(j, k, L, N, A, w, T, ep, ec):
    H = h(T, L[j-1], w, ep, ec,A) 
    phij = N[j-1].dot(H.dot(N[j-1]))/2
    return phij/(1-(k.dot(N[j-1]))**2) #expandir aqui

# %% [markdown]
# \begin{equation}
# \Psi (t) = \frac{n^i h_{ij} n^j}{2(1 - (\hat{k}\cdot \hat{n})^2)}
# \end{equation}

# %% [markdown]
# ## Símbolos

# %%
phi, theta, t, w, L, A , psi, sigma= symbols('ϕ θ t ω L A ψ σ')

# %% [markdown]
# ## Sistemas de coordenadas e vetores usando o sympy

# %%
DetFrame = ReferenceFrame("Det")
WaveFrame = ReferenceFrame("Wave")
WaveFrame.orient(DetFrame, "body", (phi, theta, psi), 'zxz')

# %%
vx = WaveFrame.x
vy = WaveFrame.y
vz = WaveFrame.z
dbaseii = outer(vx, vx)
dbaseij = outer(vx, vy)
dbaseik = outer(vx, vz)
dbaseji = outer(vy, vx)
dbasejj = outer(vy, vy)
dbasejk = outer(vy, vz)
dbaseki = outer(vz, vx)
dbasekj = outer(vz, vy)
dbasekk = outer(vz, vz)

# %%
e_plus  = dbaseii - dbasejj
e_cross = dbaseij + dbaseji

# %%
#n no referencial do detector
n2 = cos(sigma)*DetFrame.x + sin(sigma)*DetFrame.y
n3 = cos(sigma)*DetFrame.x - sin(sigma)*DetFrame.y

# %%
k = WaveFrame.z

# %% [markdown]
# ## Defining posições dos satélites

# %%
O = Point('O') #origin

# %%
O.set_vel(DetFrame, 0)

# %%
#seting p1, p2, p3
p1 = Point(r'P_1') 
p2 = Point(r'P_2')
p3 = Point(r'P_3')
#r1, r2, r3, gamma1, gamma2, gamma3 = symbols(r'r_1 r_2 r_3 \gamma_1 \gamma_2 \gamma_3') #dist from org & phase angle
l = Symbol('l')
p1.set_pos(O, l*cos(0     )*DetFrame.x + l*sin(0     )*DetFrame.y + 0*DetFrame.z)
p2.set_pos(O, l*cos(2*pi/3)*DetFrame.x + l*sin(2*pi/3)*DetFrame.y + 0*DetFrame.z)
p3.set_pos(O, l*cos(4*pi/3)*DetFrame.x + l*sin(4*pi/3)*DetFrame.y + 0*DetFrame.z)

# %%
P1 = p1.pos_from(O)
P2 = p2.pos_from(O)
P3 = p3.pos_from(O)
P = [P1, P2, P3]

# %%
#setting n's, according to KTV notation
n1 = p2.pos_from(p3)
n2 = p3.pos_from(p1)
n3 = p1.pos_from(p2)
L1 = n1.magnitude()
L2 = n2.magnitude()
L3 = n3.magnitude()
N = [n1, n2, n3]
L = [L1, L2, L3]

# %% [markdown]
# ## Início do cálculo do interferômetro

# %%
PARAMETERS = (k,L,N,P,A,w,t, e_plus, e_cross)

# %%
def delay(func, D):
    return func.subs(w*t, w*t - L[D-1])

def ygw(i,j,k,L,N,P,A,w,T, ep, ec):
    m = abs(6-i-j)-1
    return (1+ k.dot(N[m]))*\
           (PSIj(m, k, L, N, A, w, T + k.dot(P[i-1]) - L[m], ep, ec)\
            - PSIj(m,k, L, N, A, w, T + k.dot(P[j-1]), ep, ec))    #   # T + k.dot(P[i]) - L[m]) , T + k.dot(P[j]))

def ygwD(i,j,k,L,N,P,A,w,T, ep, ec, D): #Ygw com delay
    #delay = L[D]
    return delay(ygw(i,j,k,L,N,P,A,w,T, ep, ec), D)
    
def yij(i,j, parms = PARAMETERS):
    k,L,N,P,A,w,T, ep, ec = parms
    return ygw(i,j,k,L,N,P,A,w,T, ep, ec)

def yijD(i,j,D):
    return delay(yij(i,j),D)

def yijDD(i,j,D, E):
    return delay(delay(yij(i,j),D),E)

# %%
f = A*cos(w*t)
f
# Out:
# A*cos(t*ω)

# %%
delay(f, 2)
# Out:
# A*cos(t*ω - sqrt(3)*sqrt(l**2))

# %%
X =   (yij(3,1) + yijD(1,3,2))\
   + delay(delay((yij(2,1) + yijD(1,2,3)),2),2)\
   - (yij(2,1) + yijD(1,2,3))\
   - delay(delay(yij(3,1)+yijD(1,3,2),2),2)\
   - delay(delay(delay(delay(\
      (yij(3,1) + yijD(1,3,2))\
   + delay(delay((yij(2,1) + yijD(1,2,3)),2),2)\
   - (yij(2,1) + yijD(1,2,3))\
   - delay(delay(yij(3,1)+yijD(1,3,2),2),2)\
     ,2),2),3),3)

# %%
#X = sympy.trigsimp(X)

# %%
y1 = yijD(3,1,2) - yij(2,3)

# %%
#calculando M
X=sympy.trigsimp(y1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'finite'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_positive'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-8320aba031a8> in <module>
#       1 #calculando M
# ----> 2 X=sympy.trigsimp(y1)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\trigsimp.py in futrig(e, **kwargs)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\trigsimp.py in _futrig(e, **kwargs)
#    1167             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1168         )]
# -> 1169     e = greedy(tree, objective=Lops)(e)
#    1170
#    1171     if coeff is not None:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\strategies\core.py in minrule(expr)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\strategies\core.py in <listcomp>(.0)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\strategies\core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\strategies\core.py in minrule(expr)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\strategies\core.py in <listcomp>(.0)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     660             a1 = s.pop()
#     661             a2 = s.pop()
# --> 662             args.append((-cos(a1 + a2) + cos(a1 - a2))/2)
#     663         if s:
#     664             args.append(sin(s.pop()))
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     463
#     464         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 465         result = super().__new__(cls, *args, **options)
#     466         if evaluate and isinstance(result, cls) and result.args:
#     467             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     278
#     279         if evaluate:
# --> 280             evaluated = cls.eval(*args)
#     281             if evaluated is not None:
#     282                 return evaluated
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\functions\elementary\trigonometric.py in eval(cls, arg)
#     571             return cls(-arg)
#     572
# --> 573         i_coeff = arg.as_coefficient(S.ImaginaryUnit)
#     574         if i_coeff is not None:
#     575             return cosh(i_coeff)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\expr.py in as_coefficient(self, expr)
#    1687         """
#    1688
# -> 1689         r = self.extract_multiplicatively(expr)
#    1690         if r and not r.has(expr):
#    1691             return r
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\expr.py in extract_multiplicatively(self, c)
#    2183                 return x
#    2184
# -> 2185         quotient = self / c
#    2186         if self.is_Number:
#    2187             if self is S.Infinity:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     249             if not isinstance(other, expectedcls):
#     250                 return retval
# --> 251             return func(self, other)
#     252
#     253         return _func
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     125                     if f is not None:
#     126                         return f(self)
# --> 127             return func(self, other)
#     128         return binary_op_wrapper
#     129     return priority_decorator
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\expr.py in __div__(self, other)
#     233     @call_highest_priority('__rdiv__')
#     234     def __div__(self, other):
# --> 235         return Mul(self, Pow(other, S.NegativeOne))
#     236
#     237     @sympify_return([('other', 'Expr')], NotImplemented)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\operations.py in __new__(cls, *args, **options)
#      50             return args[0]
#      51
# ---> 52         c_part, nc_part, order_symbols = cls.flatten(args)
#      53         is_commutative = not nc_part
#      54         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     195                 seq = [a, b]
#     196             assert not a is S.One
# --> 197             if not a.is_zero and a.is_Rational:
#     198                 r, b = b.as_coeff_Mul()
#     199                 if b.is_Add:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\expr.py in _eval_is_negative(self)
#     869         if finite is False:
#     870             return False
# --> 871         extended_negative = self.is_extended_negative
#     872         if finite is True:
#     873             return extended_negative
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\add.py in _eval_is_extended_negative(self)
#     733         neg = nonpos = nonneg = unknown_sign = False
#     734         saw_INF = set()
# --> 735         args = [a for a in self.args if not a.is_zero]
#     736         if not args:
#     737             return False
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\add.py in <listcomp>(.0)
#     733         neg = nonpos = nonneg = unknown_sign = False
#     734         saw_INF = set()
# --> 735         args = [a for a in self.args if not a.is_zero]
#     736         if not args:
#     737             return False
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\mul.py in _eval_is_imaginary(self)
#    1324         if z:
#    1325             return False
# -> 1326         if self.is_finite is False:
#    1327             return False
#    1328         elif z is False and self.is_finite is True:
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\expr.py in _eval_is_positive(self)
#     859         if finite is False:
#     860             return False
# --> 861         extended_positive = self.is_extended_positive
#     862         if finite is True:
#     863             return extended_positive
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\expr.py in _eval_is_negative(self)
#     869         if finite is False:
#     870             return False
# --> 871         extended_negative = self.is_extended_negative
#     872         if finite is True:
#     873             return extended_negative
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# c:\users\arthur\pycharmprojects\spiffy\venv\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     506     # Try assumption's prerequisites
#     507     prereq = list(_assume_rules.prereq[fact])
# --> 508     shuffle(prereq)
#     509     for pk in prereq:
#     510         if pk in assumptions:
#
# ~\AppData\Local\Programs\Python\Python38\lib\random.py in shuffle(self, x, random)
#     304             for i in reversed(range(1, len(x))):
#     305                 # pick an element in x[:i+1] with which to exchange x[i]
# --> 306                 j = randbelow(i+1)
#     307                 x[i], x[j] = x[j], x[i]
#     308         else:
#
# ~\AppData\Local\Programs\Python\Python38\lib\random.py in _randbelow_with_getrandbits(self, n)
#     252
#     253         getrandbits = self.getrandbits
# --> 254         k = n.bit_length()  # don't use (n-1) here because n can be 1
#     255         r = getrandbits(k)          # 0 <= r < 2**k
#     256         while r >= n:
#
# KeyboardInterrupt:

# %%
X=sympy.expand(X)

# %%
X
# Out:
# -(-(-sqrt(3)*l*((-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))*(A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2 - sqrt(3)*l*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ))/2)*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2)) - sin(sqrt(3)*ω*sqrt(l**2))*cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))) - A*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*sin(sqrt(3)*ω*sqrt(l**2)) + cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2)))*(-sqrt(3)*l*(-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))/2 + 3*l*(-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))/2)) + (A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2 - sqrt(3)*l*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ))/2)*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*sin(sqrt(3)*ω*sqrt(l**2)) + cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2))) + A*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2)) - sin(sqrt(3)*ω*sqrt(l**2))*cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t)))*(-sqrt(3)*l*(-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))/2 + 3*l*(-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))/2))*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ)))/4 + 3*l*((-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))*(A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2 - sqrt(3)*l*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ))/2)*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2)) - sin(sqrt(3)*ω*sqrt(l**2))*cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))) - A*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*sin(sqrt(3)*ω*sqrt(l**2)) + cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2)))*(-sqrt(3)*l*(-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))/2 + 3*l*(-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))/2)) + (A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2 - sqrt(3)*l*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ))/2)*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*sin(sqrt(3)*ω*sqrt(l**2)) + cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2))) + A*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t))*cos(sqrt(3)*ω*sqrt(l**2)) - sin(sqrt(3)*ω*sqrt(l**2))*cos(ω*(-l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t)))*(-sqrt(3)*l*(-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))/2 + 3*l*(-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))/2))*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ)))/4)/(1 - (3*l*sin(θ)*sin(ϕ)/2 + sqrt(3)*l*sin(θ)*cos(ϕ)/2)**2) + (-sqrt(3)*l*((-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))*(A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2 - sqrt(3)*l*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ))/2)*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))*cos(sqrt(3)*ω*sqrt(l**2)) - sin(sqrt(3)*ω*sqrt(l**2))*cos(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))) - A*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))*sin(sqrt(3)*ω*sqrt(l**2)) + cos(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))*cos(sqrt(3)*ω*sqrt(l**2)))*(-sqrt(3)*l*(-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))/2 + 3*l*(-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))/2)) + (A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2 - sqrt(3)*l*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ))/2)*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))*sin(sqrt(3)*ω*sqrt(l**2)) + cos(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))*cos(sqrt(3)*ω*sqrt(l**2))) + A*(sin(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2)))*cos(sqrt(3)*ω*sqrt(l**2)) - sin(sqrt(3)*ω*sqrt(l**2))*cos(ω*(-l*sin(θ)*sin(ϕ)/2 - sqrt(3)*l*sin(θ)*cos(ϕ)/2 + t - sqrt(3)*sqrt(l**2))))*(-sqrt(3)*l*(-sin(ψ)*sin(ϕ) + cos(θ)*cos(ψ)*cos(ϕ))/2 + 3*l*(-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))/2))*(sin(ψ)*cos(θ)*cos(ϕ) + sin(ϕ)*cos(ψ)))/4 + 3*l*((-sin(ψ)*cos(ϕ) - sin(ϕ)*cos(θ)*cos(ψ))*(A*(3*l*(-sin(ψ)*sin(ϕ)*cos(θ) + cos(ψ)*cos(ϕ))/2  ...

# %%
#M=sympy.trigsimp(M)

# %%
F_mais=X.coeff(cos(w*t))
F_cruzado=X.coeff(sin(w*t))

# %%
F_cruzado
# Out:
# 0

# %%
f_mais = sympy.lambdify([   phi, theta, w, A, l], F_mais)
f_cruzado = sympy.lambdify([phi, theta, w, A, l], F_cruzado)
M_eval = sympy.lambdify([phi, theta, w, A, l], M)

# %%
f_mais

# %%
#defining parameters
phi_value, theta_value = np.mgrid[-np.pi:np.pi:100j, 0:np.pi:100j]
arm=5e9/3e8 #segundos

f=10**-3 #Hz
freq=2*np.pi*f
a=1

# %%
#atribuindos os valores acima nas funções
#                       [phi          , theta       , w   , A, r1, r2, r3, gamma1, gamma2, gamma3]
f_mais_data    = f_mais((phi_value), (theta_value), freq, a, arm)
f_cruzado_data = f_cruzado((phi_value),(theta_value), freq, a, arm)

# %%
f_mais_data

# %%
#plot phi, theta e F
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(phi_value, theta_value,(f_mais_data),color='b')
#ax.plot_surface(phi_value, theta_value,(f_cruzado_data),color='g')
#ax.plot_surface(phi_value, theta_value,(f_cruzado_data-f_mais_data),color='g')
ax.set_xlabel('phi')
ax.set_ylabel('theta')
ax.set_zlabel('F+')
plt.show()

# %%
#plot x,y,z

fig = plt.figure()
ax = fig.gca(projection='3d')

x_mais=(f_mais_data)*np.sin(theta_value)*np.sin(phi_value)
y_mais=-(f_mais_data)*np.sin(theta_value)*np.cos(phi_value)
z_mais=(f_mais_data)*np.cos(theta_value)

x_cruzado=(f_cruzado_data)*np.sin(theta_value)*np.sin(phi_value)
y_cruzado=-(f_cruzado_data)*np.sin(theta_value)*np.cos(phi_value)
z_cruzado=(f_cruzado_data)*np.cos(theta_value)

ax.plot_surface(x_mais,y_mais,z_mais,color='b')
#ax.plot_surface(x_cruzado,y_cruzado,z_cruzado,color='g')
#ax.plot_surface((x_cruzado-x_mais),(y_cruzado-y_mais),(z_cruzado-z_mais),color='g', label = 'F_cruzado')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()
